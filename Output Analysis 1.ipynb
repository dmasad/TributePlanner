# %%
import json
from itertools import combinations
from collections import defaultdict

import numpy as np
import networkx as nx
import pandas

import matplotlib.pyplot as plt

import scipy.stats
import statsmodels.api as sm

# %%
# %matplotlib inline

# %% [markdown]
# # Analyzing model output
#
# These are done in no particular order, and especially not the order they will appear in in the paper.

# %% [markdown]
# ## Advantage of lookahead in heterogenous model
#
# Load and combine the data from several different runs, for a total of 50 runs, such that each run has a different graph. Agent lookahead varies between 0 and 5. Run some statistics to check whether the distributions of final wealth differ by lookahead, and then run a regression to figure out the effect.

# %%
with open("Outputs/batch1.json") as f:
    data_1 = json.load(f)
    
with open("Outputs/batch3.json") as f:
    data_2 = json.load(f)

with open("Outputs/batch4.json") as f:
    data_3 = json.load(f)

# %%
raw_data = data_1 + data_2 + data_3

# %%
records = []
for i, model in enumerate(raw_data):
    G = nx.from_dict_of_dicts(model["graph"])
    degrees = G.degree()
    for id_num, agent in model["agents"].items():
        agent["degree"] = degrees[id_num]
        agent["iteration"] = i
        records.append(agent)

# %%
agent_data = pandas.DataFrame(records)

# %%
agent_data.head()
# Out:
#    degree  iteration  max_depth  starting_wealth       wealth
# 0       2          0          3              349     0.000000
# 1       2          0          2              443  2396.687500
# 2       2          0          2              337    40.000000
# 3       2          0          4              307  2231.559998
# 4       3          0          2              495    40.000000

# %%
agent_data.corr()
# Out:
#                    degree  iteration  max_depth  starting_wealth    wealth
# degree           1.000000   0.000000  -0.021262        -0.051346 -0.259759
# iteration        0.000000   1.000000  -0.122145         0.014666  0.040034
# max_depth       -0.021262  -0.122145   1.000000        -0.022443 -0.047626
# starting_wealth -0.051346   0.014666  -0.022443         1.000000  0.210101
# wealth          -0.259759   0.040034  -0.047626         0.210101  1.000000

# %%
plt.scatter(agent_data.wealth, agent_data.max_depth)

# %%
d0 = agent_data.wealth[agent_data.max_depth==0]
d1 = agent_data.wealth[agent_data.max_depth==1]
d2 = agent_data.wealth[agent_data.max_depth==2]
d3 = agent_data.wealth[agent_data.max_depth==3]
d4 = agent_data.wealth[agent_data.max_depth==4]
d5 = agent_data.wealth[agent_data.max_depth==5]

# %%
scipy.stats.ttest_ind(d0, d4)
# Out:
# (array(0.5581932531503468), 0.57742995973310562)

# %%
model = sm.OLS(agent_data.wealth, agent_data[["degree", "max_depth", "starting_wealth"]])
fit = model.fit()
print fit.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 wealth   R-squared:                       0.102
# Model:                            OLS   Adj. R-squared:                  0.098
# Method:                 Least Squares   F-statistic:                     28.25
# Date:                Thu, 01 May 2014   Prob (F-statistic):           2.40e-12
# Time:                        10:50:08   Log-Likelihood:                -4255.8
# No. Observations:                 500   AIC:                             8518.
# Df Residuals:                     497   BIC:                             8530.
# Df Model:                           2
# ===================================================================================
#                       coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------
# degree           -517.0682     90.954     -5.685      0.000      -695.769  -338.367
# max_depth         -25.8586     40.760     -0.634      0.526      -105.941    54.224
# starting_wealth     5.9599      0.502     11.868      0.000         4.973     6.947
# ==============================================================================
# Omnibus:                       50.676   Durbin-Watson:                   2.890
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               26.670
# Skew:                           0.403   Prob(JB):                     1.62e-06
# Kurtosis:                       2.206   Cond. No.                         692.
# ==============================================================================

# %% [markdown]
# What if we drop the peripheral agents?

# %%
winning_agents = agent_data[agent_data.wealth > 500]

# %%
model = sm.OLS(winning_agents.wealth, winning_agents[["degree", "max_depth", "starting_wealth"]])
fit = model.fit()
print fit.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 wealth   R-squared:                      -0.096
# Model:                            OLS   Adj. R-squared:                 -0.104
# Method:                 Least Squares   F-statistic:                    -11.86
# Date:                Thu, 01 May 2014   Prob (F-statistic):               1.00
# Time:                        10:50:09   Log-Likelihood:                -2196.0
# No. Observations:                 274   AIC:                             4398.
# Df Residuals:                     271   BIC:                             4409.
# Df Model:                           2
# ===================================================================================
#                       coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------
# degree            429.5231     85.944      4.998      0.000       260.321   598.725
# max_depth           5.7729     34.660      0.167      0.868       -62.465    74.010
# starting_wealth     3.6823      0.418      8.817      0.000         2.860     4.504
# ==============================================================================
# Omnibus:                        5.833   Durbin-Watson:                   1.377
# Prob(Omnibus):                  0.054   Jarque-Bera (JB):                6.200
# Skew:                           0.239   Prob(JB):                       0.0450
# Kurtosis:                       3.562   Cond. No.                         816.
# ==============================================================================

# %% [markdown]
# ### Fixed network structure

# %%
with open("Outputs/batch5.json") as f:
    data_4 = json.load(f)

# %%
records = []
for i, model in enumerate(data_4):
    G = nx.from_dict_of_dicts(model["graph"])
    degrees = G.degree()
    for id_num, agent in model["agents"].items():
        agent["degree"] = degrees[id_num]
        agent["iteration"] = i
        records.append(agent)

# %%
agent_data2 = pandas.DataFrame(records)

# %%
agent_data2.corr(method='spearman')
# Out:
#                    degree  iteration  max_depth  starting_wealth    wealth
# degree           1.000000   0.000000   0.080924        -0.011449 -0.660123
# iteration        0.000000   1.000000   0.017185         0.007705  0.035782
# max_depth        0.080924   0.017185   1.000000         0.060667 -0.078438
# starting_wealth -0.011449   0.007705   0.060667         1.000000  0.017697
# wealth          -0.660123   0.035782  -0.078438         0.017697  1.000000

# %%
agent_data2["Const."] = 1

# %%
model = sm.OLS(agent_data2.wealth, agent_data2[["Const.", "degree", "max_depth", "starting_wealth"]])

# %%
fit = model.fit()

# %%
print fit.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 wealth   R-squared:                       0.571
# Model:                            OLS   Adj. R-squared:                  0.569
# Method:                 Least Squares   F-statistic:                     220.2
# Date:                Thu, 01 May 2014   Prob (F-statistic):           8.85e-91
# Time:                        10:50:13   Log-Likelihood:                -4024.3
# No. Observations:                 500   AIC:                             8057.
# Df Residuals:                     496   BIC:                             8073.
# Df Model:                           3
# ===================================================================================
#                       coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------
# Const.           3365.2715    249.025     13.514      0.000      2875.998  3854.545
# degree          -1123.2037     44.042    -25.503      0.000     -1209.737 -1036.671
# max_depth         -11.7628     19.812     -0.594      0.553       -50.688    27.163
# starting_wealth     0.8349      0.575      1.453      0.147        -0.294     1.964
# ==============================================================================
# Omnibus:                       20.417   Durbin-Watson:                   2.149
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               28.491
# Skew:                           0.352   Prob(JB):                     6.51e-07
# Kurtosis:                       3.933   Cond. No.                     2.95e+03
# ==============================================================================
#
# The condition number is large, 2.95e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
dummies = pandas.get_dummies(agent_data2.max_depth, "Depth")
cols = []
for col in dummies:
    agent_data2[col] = dummies[col]
    cols.append(col)

# %%
cols
# Out:
# ['Depth_0', 'Depth_1', 'Depth_2', 'Depth_3', 'Depth_4', 'Depth_5']

# %%
model = sm.OLS(agent_data2.wealth, agent_data2[["Const.", "degree", "starting_wealth"] 
                                            + cols[1:]])
fit = model.fit()
print fit.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 wealth   R-squared:                       0.574
# Model:                            OLS   Adj. R-squared:                  0.568
# Method:                 Least Squares   F-statistic:                     94.78
# Date:                Thu, 01 May 2014   Prob (F-statistic):           4.50e-87
# Time:                        10:50:15   Log-Likelihood:                -4022.5
# No. Observations:                 500   AIC:                             8061.
# Df Residuals:                     492   BIC:                             8095.
# Df Model:                           7
# ===================================================================================
#                       coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------
# Const.           3342.8685    258.181     12.948      0.000      2835.596  3850.141
# degree          -1116.0092     44.258    -25.216      0.000     -1202.966 -1029.052
# starting_wealth     0.8414      0.576      1.461      0.145        -0.290     1.973
# Depth_1           -50.1297    112.623     -0.445      0.656      -271.410   171.151
# Depth_2             1.1346    119.691      0.009      0.992      -234.035   236.304
# Depth_3           106.2024    118.382      0.897      0.370      -126.395   338.799
# Depth_4          -108.9312    115.004     -0.947      0.344      -334.890   117.027
# Depth_5           -71.0015    118.216     -0.601      0.548      -303.271   161.268
# ==============================================================================
# Omnibus:                       16.301   Durbin-Watson:                   2.153
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               20.868
# Skew:                           0.320   Prob(JB):                     2.94e-05
# Kurtosis:                       3.769   Cond. No.                     3.18e+03
# ==============================================================================
#
# The condition number is large, 3.18e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Distribution of outcomes and wars with heuristic, zero-lookahead, and heterogenous lookahead

# %%
with open("Outputs/batch6.json") as f:
    heuristic_data = json.load(f)

with open("Outputs/batch7.json") as f:
    nolook_data = json.load(f)

# %%
final_wealth_1 = []
for model in heuristic_data:
    final_wealth_1 += [agent["wealth"] for agent in model["agents"].values()]
    
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111)

ax.hist(final_wealth_1, bins=np.linspace(0, 5000, 11))

ax.set_xlim(0, 5000)
ax.set_ylim(0, 300)
ax.grid(True)
ax.set_xlabel("Final Wealth", fontsize=16)
ax.set_ylabel("Agent Count", fontsize=16)

# %%
final_wealth_2 = []
for model in nolook_data:
    final_wealth_2 += [agent["wealth"] for agent in model["agents"].values()]

fig = plt.figure(figsize=(12,6))
ax = fig.add_subplot(111)

ax.hist(final_wealth_2, bins=np.linspace(0, 5000, 11))

ax.set_xlim(0, 5000)
ax.set_ylim(0, 300)

ax.grid(True)
ax.set_xlabel("Final Wealth", fontsize=16)
ax.set_ylabel("Agent Count", fontsize=16)

# %%
final_wealth_3 = []
for model in raw_data:
    final_wealth_3 += [agent["wealth"] for agent in model["agents"].values()]

    
    
fig = plt.figure(figsize=(12,6))
ax = fig.add_subplot(111)

ax.hist(final_wealth_3, bins=np.linspace(0, 5000, 11))

ax.set_xlim(0, 5000)
ax.set_ylim(0, 300)

ax.grid(True)
ax.set_xlabel("Final Wealth", fontsize=16)
ax.set_ylabel("Agent Count", fontsize=16)

# %%
final_wealth_4 = []
for model in data_4:
    final_wealth_4 += [agent["wealth"] for agent in model["agents"].values()]


fig = plt.figure(figsize=(12,6))
ax = fig.add_subplot(111)

ax.hist(final_wealth_4, bins=np.linspace(0, 5000, 11))

ax.set_xlim(0, 5000)
ax.set_ylim(0, 300)

ax.grid(True)
ax.set_xlabel("Final Wealth", fontsize=16)
ax.set_ylabel("Agent Count", fontsize=16)

# %% [markdown]
# ### Check whether these are drawn from the same distribution?

# %%
wealth_dists = [final_wealth_1, final_wealth_2, final_wealth_3, final_wealth_4]

# %%
for s1, s2 in combinations(wealth_dists, 2):
    print scipy.stats.mannwhitneyu(s1, s2)
# Out:
# (104840.0, 4.8919866171783284e-06)
# (115313.0, 0.016822113150662021)
# (120372.0, 0.15501116372361612)
# (118551.0, 0.078544207269494473)
# (110508.5, 0.00073486190242274781)
# (119826.0, 0.12812233060625589)

# %%
for s1, s2 in combinations(wealth_dists, 2):
    print scipy.stats.ks_2samp(s1, s2)
# Out:
# (0.21799999999999997, 6.5303389695936758e-11)
# (0.20799999999999996, 5.6871919000726656e-10)
# (0.15800000000000003, 6.2053101176349112e-06)
# (0.093999999999999972, 0.022458470313574272)
# (0.24000000000000005, 3.9055527502130253e-13)
# (0.22200000000000003, 2.6705121087196955e-11)

# %% [markdown]
# ## War sizes and paces

# %%
np.linspace(-0.5,3.5,5)
# Out:
# array([-0.5,  0.5,  1.5,  2.5,  3.5])

# %%
war_counts_1 = defaultdict(int)
for model in heuristic_data:
    for turn in model["war_series"]:
        war_counts_1[turn] += 1

fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111)

#ax.hist(war_counts_1, bins=np.linspace(-0.5, 3.5, 5))
ax.bar(war_counts_1.keys(), war_counts_1.values(), align='center')

ax.set_xticks(range(0,4))
ax.set_xlim(-0.5,3.5)
ax.set_ylim(0, 2500)

ax.grid(True)
ax.set_xlabel("Wars per Turn", fontsize=16)
ax.set_ylabel("Total Turn Count", fontsize=16)

# %%
war_counts_2 = defaultdict(int)
for model in nolook_data:
    for turn in model["war_series"]:
        war_counts_2[turn] += 1

fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111)

ax.bar(war_counts_2.keys(), war_counts_2.values(), align='center')

ax.set_xticks(range(0,4))
ax.set_xlim(-0.5,3.5)
ax.set_ylim(0, 2500)

ax.grid(True)
ax.set_xlabel("Wars per Turn", fontsize=16)
ax.set_ylabel("Total Turn Count", fontsize=16)

# %%
war_counts_3 = defaultdict(int)
for model in raw_data:
    for turn in model["war_series"]:
        war_counts_3[turn] += 1

fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111)

ax.bar(war_counts_3.keys(), war_counts_3.values(), align='center')

ax.set_xticks(range(0,4))
ax.set_xlim(-0.5,3.5)
ax.set_ylim(0, 2500)

ax.grid(True)
ax.set_xlabel("Wars per Turn", fontsize=16)
ax.set_ylabel("Total Turn Count", fontsize=16)

# %%
war_counts_4 = defaultdict(int)
for model in data_4:
    for turn in model["war_series"]:
        war_counts_4[turn] += 1

fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111)

ax.bar(war_counts_4.keys(), war_counts_4.values(), align='center')

ax.set_xticks(range(0,4))
ax.set_xlim(-0.5,3.5)
ax.set_ylim(0, 2500)

ax.grid(True)
ax.set_xlabel("Wars per Turn", fontsize=16)
ax.set_ylabel("Total Turn Count", fontsize=16)

# %%
war_dists = [war_counts_1, war_counts_2, war_counts_3, war_counts_4]
for s1, s2 in combinations(war_dists, 2):
    print scipy.stats.mannwhitneyu(s1, s2)
# Out:
# (8134041.0, 6.5982312925217099e-202)
# (8136941.0, 1.8251834646936615e-201)
# (10764759.0, 1.3586464543753598e-33)
# (12352462.0, 0.1530889139678403)
# (10031307.5, 5.870645778461405e-66)
# (9964695.5, 1.2356967274519784e-69)

# %% [markdown]
# ## Sample Runs

# %%
fig = plt.figure(figsize=(12,4))
ax = fig.add_subplot(111)

for agent, series in heuristic_data[7]["agent_wealth_series"].items():
    ax.plot(series)

ax.grid(True)
ax.set_xlabel("Turn", fontsize=16)
ax.set_ylabel("Agent Wealth", fontsize=16)

# %%
fig = plt.figure(figsize=(12,4))
ax = fig.add_subplot(111)

for agent, series in nolook_data[7]["agent_wealth_series"].items():
    ax.plot(series)

ax.grid(True)
ax.set_xlabel("Turn", fontsize=16)
ax.set_ylabel("Agent Wealth", fontsize=16)

# %%
fig = plt.figure(figsize=(12,4))
ax = fig.add_subplot(111)

for agent, series in raw_data[1]["agent_wealth_series"].items():
    ax.plot(series)

ax.grid(True)
ax.set_xlabel("Turn", fontsize=16)
ax.set_ylabel("Agent Wealth", fontsize=16)

# %%
fig = plt.figure(figsize=(12,4))
ax = fig.add_subplot(111)

for agent, series in data_4[7]["agent_wealth_series"].items():
    ax.plot(series)

ax.grid(True)
ax.set_xlabel("Turn", fontsize=16)
ax.set_ylabel("Agent Wealth", fontsize=16)
