# %%
from TributeModel import Model

import networkx as nx
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
#G = nx.grid_2d_graph(10,10)
G = nx.watts_strogatz_graph(10, 3, 0.2)
#G = nx.scale_free_graph(10)
#G = G.to_undirected()
#G = nx.erdos_renyi_graph(10, 1)

G = nx.relabel_nodes(G, {tup: i for i, tup in enumerate(G.nodes())})
m = Model(G)
m.verbose = True
m.tribute = 100
#m.actions_per_turn = 10
pos = nx.spring_layout(G)

# %%
for i in range(100):
    m.step()
    print "*\t*\t*"
# Out:
# - Begin internal simulation -
# War between 0 and 9
# - End internal simulation -
# - Begin internal simulation -
# War between 0 and 7
# - End internal simulation -
# - Begin internal simulation -
# War between 4 and 3
# - End internal simulation -
# - Begin internal simulation -
# War between 4 and 5
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 6
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 6
# - End internal simulation -
# 5 paying tribute to 6
# *	*	*
# - Begin internal simulation -
# 2 paying tribute to 3
# - End internal simulation -
# - Begin internal simulation -
# 4 paying tribute to 3
# - End internal simulation -
# 2 paying tribute to 3
# - Begin internal simulation -
# War between 4 and 3
# - End internal simulation -
# - Begin internal simulation -
# War between 4 and 5
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 6
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 6
# - End internal simulation -
# 5 paying tribute to 6
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 0
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 0
# - End internal simulation -
# 9 paying tribute to 0
# - Begin internal simulation -
# 5 paying tribute to 1
# - End internal simulation -
# 5 paying tribute to 1
# - Begin internal simulation -
# 2 paying tribute to 3
# - End internal simulation -
# - Begin internal simulation -
# 4 paying tribute to 3
# - End internal simulation -
# 2 paying tribute to 3
# *	*	*
# - Begin internal simulation -
# 5 paying tribute to 1
# - End internal simulation -
# 5 paying tribute to 1
# - Begin internal simulation -
# 2 paying tribute to 3
# - End internal simulation -
# - Begin internal simulation -
# 4 paying tribute to 3
# - End internal simulation -
# 2 paying tribute to 3
# - Begin internal simulation -
# 5 paying tribute to 6
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 6
# - End internal simulation -
# 7 paying tribute to 6
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 0
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 0
# - End internal simulation -
# 9 paying tribute to 0
# - Begin internal simulation -
# 3 paying tribute to 4
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 4
# - End internal simulation -
# 3 paying tribute to 4
# - Begin internal simulation -
# 5 paying tribute to 6
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 6
# - End internal simulation -
# 7 paying tribute to 6
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 8
# - End internal simulation -
# 9 paying tribute to 8
# - Begin internal simulation -
# War between 2 and 3
# - End internal simulation -
# - Begin internal simulation -
# 3 paying tribute to 4
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 4
# - End internal simulation -
# 3 paying tribute to 4
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 8
# - End internal simulation -
# 9 paying tribute to 8
# - Begin internal simulation -
# 9 paying tribute to 0
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 0
# - End internal simulation -
# 9 paying tribute to 0
# - Begin internal simulation -
# 0 paying tribute to 7
# - End internal simulation -
# - Begin internal simulation -
# 9 paying tribute to 7
# - End internal simulation -
# - Begin internal simulation -
# 6 paying tribute to 7
# - End internal simulation -
# 0 paying tribute to 7
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 0
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 0
# - End internal simulation -
# 7 paying tribute to 0
# - Begin internal simulation -
# War between 2 and 3
# - End internal simulation -
# - Begin internal simulation -
# 0 paying tribute to 7
# - End internal simulation -
# - Begin internal simulation -
# 9 paying tribute to 7
# - End internal simulation -
# - Begin internal simulation -
# 6 paying tribute to 7
# - End internal simulation -
# 0 paying tribute to 7
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 8
# - End internal simulation -
# 9 paying tribute to 8
# - Begin internal simulation -
# 5 paying tribute to 1
# - End internal simulation -
# 5 paying tribute to 1
# - Begin internal simulation -
# War between 2 and 3
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 8
# - End internal simulation -
# 9 paying tribute to 8
# - Begin internal simulation -
# 9 paying tribute to 0
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 0
# - End internal simulation -
# 7 paying tribute to 0
# - Begin internal simulation -
# War between 2 and 3
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# War between 9 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 8
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 7
# - End internal simulation -
# - Begin internal simulation -
# 2 paying tribute to 3
# - End internal simulation -
# - Begin internal simulation -
# 4 paying tribute to 3
# - End internal simulation -
# 2 paying tribute to 3
# - Begin internal simulation -
# 5 paying tribute to 6
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 6
# - End internal simulation -
# 5 paying tribute to 6
# *	*	*
# - Begin internal simulation -
# War between 2 and 3
# - End internal simulation -
# - Begin internal simulation -
# War between 5 and 1
# - End internal simulation -
# - Begin internal simulation -
# War between 5
# and 4
# - End internal simulation -
# - Begin internal simulation -
# War between 5 and 6
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 6
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 6
# - End internal simulation -
# 7 paying tribute to 6
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 0
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 0
# - End internal simulation -
# 7 paying tribute to 0
# - Begin internal simulation -
# 5 paying tribute to 1
# - End internal simulation -
# 5 paying tribute to 1
# - Begin internal simulation -
# War between 7 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 9
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 6
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 0
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 0
# - End internal simulation -
# 7 paying tribute to 0
# - Begin internal simulation -
# War between 9 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 8
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 7
# - End internal simulation -
# - Begin internal simulation -
# War between 2 and 3
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 0
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 0
# - End internal simulation -
# 9 paying tribute to 0
# - Begin internal simulation -
# War between 5 and 1
# - End internal simulation -
# - Begin internal simulation -
# War between 5 and 4
# - End internal simulation -
# - Begin internal simulation -
# War between 5 and 6
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# War between 9 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 8
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 7
# - End internal simulation -
# - Begin internal simulation -
# War between 5 and 1
# - End internal simulation -
# - Begin internal simulation -
# War between 5 and 4
# - End internal simulation -
# - Begin internal simulation -
# War between 5 and 6
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 9
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 6
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# 2 paying tribute to 3
# - End internal simulation -
# - Begin internal simulation -
# 4 paying tribute to 3
# - End internal simulation -
# 2 paying tribute to 3
# - Begin internal simulation -
# 3 paying tribute to 4
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 4
# - End internal simulation -
# 3 paying tribute to 4
# - Begin internal simulation -
# War between 7 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 9
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 6
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# War between 9 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 8
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 7
# - End internal simulation -
# - Begin internal simulation -
# 2 paying tribute to 3
# - End internal simulation -
# - Begin internal simulation -
# 4 paying tribute to 3
# - End internal simulation -
# 2 paying tribute to 3
# - Begin internal simulation -
# 3 paying tribute to 4
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 4
# - End internal simulation -
# 3 paying tribute to 4
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 8
# - End internal simulation -
# 9 paying tribute to 8
# - Begin internal simulation -
# War between 2 and 3
# - End internal simulation -
# - Begin internal simulation -
# War between 5 and 1
# - End internal simulation -
# - Begin internal simulation -
# War between 5 and 4
# - End internal simulation -
# - Begin internal simulation -
# War between 5 and 6
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# War between 2 and 3
# - End internal simulation -
# - Begin internal simulation -
# 2 paying tribute to 3
# - End internal simulation -
# - Begin internal simulation -
# 4 paying tribute to 3
# - End internal simulation -
# 4 paying tribute to 3
# - Begin internal simulation -
# 3 paying tribute to 4
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 4
# - End internal simulation -
# 3 paying tribute to 4
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 0
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 0
# - End internal simulation -
# 7 paying tribute to 0
# - Begin internal simulation -
# War between 2 and 3
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 9
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 6
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 8
# - End internal simulation -
# 9 paying tribute to 8
# - Begin internal simulation -
# War between 2 and 3
# - End internal simulation -
# - Begin internal simulation -
# 2 paying tribute to 3
# - End internal simulation -
# - Begin internal simulation -
# 4 paying tribute to 3
# - End internal simulation -
# 2 paying tribute to 3
# *	*	*
# - Begin internal simulation -
# War between 2 and 3
# - End internal simulation -
# - Begin internal simulation -
# 3 paying tribute to 4
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 4
# - End internal simulation -
# 3 paying tribute to 4
# - Begin internal simulation -
# War between 5 and 1
# - End internal simulation -
# - Begin internal simulation -
# War between 5 and 4
# - End internal simulation -
# - Begin internal simulation -
# War between 5 and 6
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# War between 2 and 3
# - End internal simulation -
# - Begin internal simulation -
# 2 paying tribute to 3
# - End internal simulation -
# - Begin internal simulation -
# 4 paying tribute to 3
# - End internal simulation -
# 4 paying tribute to 3
# - Begin internal simulation -
# War between 5 and 1
# - End internal simulation -
# - Begin internal simulation -
# War between 5 and 4
# - End internal simulation -
# - Begin internal simulation -
# War between 5 and 6
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 8
# - End internal simulation -
# 9 paying tribute to 8
# - Begin internal simulation -
# 2 paying tribute to 3
# - End internal simulation -
# - Begin internal simulation -
# 4 paying tribute to 3
# - End internal simulation -
# 4 paying tribute to 3
# - Begin internal simulation -
# 3 paying tribute to 4
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 4
# - End internal simulation -
# 3 paying tribute to 4
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 0
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 0
# - End internal simulation -
# 7 paying tribute to 0
# - Begin internal simulation -
# 9 paying tribute to 8
# - End internal simulation -
# 9 paying tribute to 8
# - Begin internal simulation -
# 2 paying tribute to 3
# - End internal simulation -
# - Begin internal simulation -
# 4 paying tribute to 3
# - End internal simulation -
# 2 paying tribute to 3
# *	*	*
# - Begin internal simulation -
# War between 9 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 8
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 7
# - End internal simulation -
# - Begin internal simulation -
# 3 paying tribute to 4
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 4
# - End internal simulation -
# 3 paying tribute to 4
# - Begin internal simulation -
# 5 paying tribute to 1
# - End internal simulation -
# 5 paying tribute to 1
# *	*	*
# - Begin internal simulation -
# War between 9 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 8
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 7
# - End internal simulation -
# - Begin internal simulation -
# 3 paying tribute to 4
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 4
# - End internal simulation -
# 3 paying tribute to 4
# - Begin internal simulation -
# War between 7 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 9
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 6
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 0
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 0
# - End internal simulation -
# 7 paying tribute to 0
# - Begin internal simulation -
# 2 paying tribute to 3
# - End internal simulation -
# - Begin internal simulation -
# 4 paying tribute to 3
# - End internal simulation -
# 4 paying tribute to 3
# - Begin internal simulation -
# War between 7 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 9
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 6
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# 5 paying tribute to 1
# - End internal simulation -
# 5 paying tribute to 1
# - Begin internal simulation -
# 2 paying tribute to 3
# - End internal simulation -
# - Begin internal simulation -
# 4 paying tribute to 3
# - End internal simulation -
# 4 paying tribute to 3
# - Begin internal simulation -
# 3 paying tribute to 4
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 4
# - End internal simulation -
# 3 paying tribute to 4
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 0
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 0
# - End internal simulation -
# 9 paying tribute to 0
# - Begin internal simulation -
# 3 paying tribute to 4
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 4
# - End internal simulation -
# 3 paying tribute to 4
# - Begin internal simulation -
# War between 5 and 1
# - End internal simulation -
# - Begin internal simulation -
# War between 5 and 4
# - End internal simulation -
# - Begin internal simulation -
# War between 5 and 6
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# War between 9 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 8
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 7
# - End internal simulation -
# - Begin internal simulation -
# 3 paying tribute to 4
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 4
# - End internal simulation -
# 3 paying tribute to 4
# - Begin internal simulation -
# 5 paying tribute to 1
# - End internal simulation -
# 5 paying tribute to 1
# *	*	*
# - Begin internal simulation -
# War between 9 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 8
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 7
# - End internal simulation -
# - Begin internal simulation -
# War between 2 and 3
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 6
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 6
# - End internal simulation -
# 5 paying tribute to 6
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 0
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 0
# - End internal simulation -
# 7 paying tribute to 0
# - Begin internal simulation -
# 5 paying tribute to 1
# - End internal simulation -
# 5 paying tribute to 1
# - Begin internal simulation -
# War between 2 and 3
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 0
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 0
# - End internal simulation -
# 7 paying tribute to 0
# - Begin internal simulation -
# 2 paying tribute to 3
# - End internal simulation -
# - Begin internal simulation -
# 4 paying tribute to 3
# - End internal simulation -
# 2 paying tribute to 3
# - Begin internal simulation -
# War between 7 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 9
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 6
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# War between 9 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 8
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 7
# - End internal simulation -
# - Begin internal simulation -
# War between 2 and 3
# - End internal simulation -
# - Begin internal simulation -
# 2 paying tribute to 3
# - End internal simulation -
# - Begin internal simulation -
# 4 paying tribute to 3
# - End internal simulation -
# 2 paying tribute to 3
# *	*	*
# - Begin internal simulation -
# 5 paying tribute to 1
# - End internal simulation -
# 5 paying tribute to 1
# - Begin internal simulation -
# War between 2 and 3
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 9
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 6
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# War between 9 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 8
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 7
# - End internal simulation -
# - Begin internal simulation -
# 3 paying tribute to 4
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 4
# - End internal simulation -
# 3 paying tribute to 4
# - Begin internal simulation -
# War between 5 and 1
# - End internal simulation -
# - Begin internal simulation -
# War between 5 and 4
# - End internal simulation -
# - Begin internal simulation -
# War between 5 and 6
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# War between 9 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 8
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 7
# - End internal simulation -
# - Begin internal simulation -
# War between 5 and 1
# - End internal simulation -
# - Begin internal simulation -
# War between 5 and 4
# - End internal simulation -
# - Begin internal simulation -
# War between 5 and 6
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 6
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 6
# - End internal simulation -
# 7 paying tribute to 6
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 0
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 0
# - End internal simulation -
# 9 paying tribute to 0
# - Begin internal simulation -
# 5 paying tribute to 1
# - End internal simulation -
# 5 paying tribute to 1
# - Begin internal simulation -
# 5 paying tribute to 6
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 6
# - End internal simulation -
# 7 paying tribute to 6
# *	*	*
# - Begin internal simulation -
# War between 9 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 8
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 7
# - End internal simulation -
# - Begin internal simulation -
# 2 paying tribute to 3
# - End internal simulation -
# - Begin internal simulation -
# 4 paying tribute to 3
# - End internal simulation -
# 2 paying tribute to 3
# - Begin internal simulation -
# War between 5 and 1
# - End internal simulation -
# - Begin internal simulation -
# War between 5 and 4
# - End internal simulation -
# - Begin internal simulation -
# War between 5 and 6
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 0
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 0
# - End internal simulation -
# 9 paying tribute to 0
# - Begin internal simulation -
# 5 paying tribute to 1
# - End internal simulation -
# 5 paying tribute to 1
# - Begin internal simulation -
# War between 7 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 9
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 6
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 0
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 0
# - End internal simulation -
# 7 paying tribute to 0
# - Begin internal simulation -
# War between 2 and 3
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 6
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 6
# - End internal simulation -
# 7 paying tribute to 6
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 0
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 0
# - End internal simulation -
# 9 paying tribute to 0
# - Begin internal simulation -
# 5 paying tribute to 6
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 6
# - End internal simulation -
# 5 paying tribute to 6
# - Begin internal simulation -
# War between 7 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 9
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 6
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 0
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 0
# - End internal simulation -
# 7 paying tribute to 0
# - Begin internal simulation -
# 3 paying tribute to 4
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 4
# - End internal simulation -
# 3 paying tribute to 4
# - Begin internal simulation -
# War between 5 and 1
# - End internal simulation -
# - Begin internal simulation -
# War between 5 and 4
# - End internal simulation -
# - Begin internal simulation -
# War between 5 and 6
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# 5 paying tribute to 1
# - End internal simulation -
# 5 paying tribute to 1
# - Begin internal simulation -
# War between 2 and 3
# - End internal simulation -
# - Begin internal simulation -
# 2 paying tribute to 3
# - End internal simulation -
# - Begin internal simulation -
# 4 paying tribute to 3
# - End internal simulation -
# 2 paying tribute to 3
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 0
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 0
# - End internal simulation -
# 9 paying tribute to 0
# - Begin internal simulation -
# War between 7 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 9
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 6
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# 5 paying tribute to 1
# - End internal simulation -
# 5 paying tribute to 1
# - Begin internal simulation -
# War between 7 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 9
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 6
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 0
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 0
# - End internal simulation -
# 7 paying tribute to 0
# - Begin internal simulation -
# War between 9 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 8
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 7
# - End internal simulation -
# - Begin internal simulation -
# 3 paying tribute to 4
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 4
# - End internal simulation -
# 3 paying tribute to 4
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 8
# - End internal simulation -
# 9 paying tribute to 8
# - Begin internal simulation -
# War between 7 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 9
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 6
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 0
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 0
# - End internal simulation -
# 7 paying tribute to 0
# - Begin internal simulation -
# 5 paying tribute to 1
# - End internal simulation -
# 5 paying tribute to 1
# - Begin internal simulation -
# 3 paying tribute to 4
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 4
# - End internal simulation -
# 3 paying tribute to 4
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 8
# - End internal simulation -
# 9 paying tribute to 8
# - Begin internal simulation -
# 3 paying tribute to 4
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 4
# - End internal simulation -
# 3 paying tribute to 4
# - Begin internal simulation -
# 5 paying tribute to 6
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 6
# - End internal simulation -
# 5 paying tribute to 6
# *	*	*
# - Begin internal simulation -
# War between 9 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 8
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 7
# - End internal simulation -
# - Begin internal simulation -
# War between 2 and 3
# - End internal simulation -
# - Begin internal simulation -
# 2 paying tribute to 3
# - End internal simulation -
# - Begin internal simulation -
# 4 paying tribute to 3
# - End internal simulation -
# 2 paying tribute to 3
# *	*	*
# - Begin internal simulation -
# War between 2 and 3
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 6
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 6
# - End internal simulation -
# 7 paying tribute to 6
# *	*	*
# - Begin internal simulation -
# War between 9 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 8
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 7
# - End internal simulation -
# - Begin internal simulation -
# 3 paying tribute to 4
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 4
# - End internal simulation -
# 3 paying tribute to 4
# - Begin internal simulation -
# 5 paying tribute to 1
# - End internal simulation -
# 5 paying tribute to 1
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 0
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 0
# - End internal simulation -
# 9 paying tribute to 0
# - Begin internal simulation -
# 5 paying tribute to 1
# - End internal simulation -
# 5 paying tribute to 1
# - Begin internal simulation -
# War between 2 and 3
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 8
# - End internal simulation -
# 9 paying tribute to 8
# - Begin internal simulation -
# 2 paying tribute to 3
# - End internal simulation -
# - Begin internal simulation -
# 4 paying tribute to 3
# - End internal simulation -
# 2 paying tribute to 3
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 8
# - End internal simulation -
# 9 paying tribute to 8
# - Begin internal simulation -
# 3 paying tribute to 4
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 4
# - End internal simulation -
# 3 paying tribute to 4
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 0
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 0
# - End internal simulation -
# 7 paying tribute to 0
# - Begin internal simulation -
# 5 paying tribute to 1
# - End internal simulation -
# 5 paying tribute to 1
# - Begin internal simulation -
# 2 paying tribute to 3
# - End internal simulation -
# - Begin internal simulation -
# 4 paying tribute to 3
# - End internal simulation -
# 4 paying tribute to 3
# *	*	*
# - Begin internal simulation -
# 5 paying tribute to 1
# - End internal simulation -
# 5 paying tribute to 1
# - Begin internal simulation -
# War between 2 and 3
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# War between 9 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 8
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 7
# - End internal simulation -
# - Begin internal simulation -
# 2 paying tribute to 3
# - End internal simulation -
# - Begin internal simulation -
# 4 paying tribute to 3
# - End internal simulation -
# 2 paying tribute to 3
# - Begin internal simulation -
# 3 paying tribute to 4
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 4
# - End internal simulation -
# 3 paying tribute to 4
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 0
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 0
# - End internal simulation -
# 9 paying tribute to 0
# - Begin internal simulation -
# War between 2 and 3
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 9
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 6
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 0
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 0
# - End internal simulation -
# 7 paying tribute to 0
# - Begin internal simulation -
# War between 2 and 3
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 6
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 6
# - End internal simulation -
# 5 paying tribute to 6
# *	*	*
# - Begin internal simulation -
# 5 paying tribute to 1
# - End internal simulation -
# 5 paying tribute to 1
# - Begin internal simulation -
# War between 2 and 3
# - End internal simulation -
# - Begin internal simulation -
# 3 paying tribute to 4
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 4
# - End internal simulation -
# 3 paying tribute to 4
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 8
# - End internal simulation -
# 9 paying tribute to 8
# - Begin internal simulation -
# 2 paying tribute to 3
# - End internal simulation -
# - Begin internal simulation -
# 4 paying tribute to 3
# - End internal simulation -
# 4 paying tribute to 3
# - Begin internal simulation -
# 5 paying tribute to 6
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 6
# - End internal simulation -
# 7 paying tribute to 6
# *	*	*
# - Begin internal simulation -
# 5 paying tribute to 1
# - End internal simulation -
# 5 paying tribute to 1
# - Begin internal simulation -
# 3 paying tribute to 4
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 4
# - End internal simulation -
# 3 paying tribute to 4
# - Begin internal simulation -
# 5 paying tribute to 6
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 6
# - End internal simulation -
# 7 paying tribute to 6
# *	*	*
# - Begin internal simulation -
# 5 paying tribute to 1
# - End internal simulation -
# 5 paying tribute to 1
# - Begin internal simulation -
# 5 paying tribute to 6
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 6
# - End internal simulation -
# 7 paying tribute to 6
# *	*	*
# - Begin internal simulation -
# 5 paying tribute to 1
# - End internal simulation -
# 5 paying tribute to 1
# - Begin internal simulation -
# War between 2 and 3
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 6
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 6
# - End internal simulation -
# 7 paying tribute to 6
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 8
# - End internal simulation -
# 9 paying tribute to 8
# - Begin internal simulation -
# 5 paying tribute to 6
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 6
# - End internal simulation -
# 5 paying tribute to 6
# - Begin internal simulation -
# War between 7 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 9
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 6
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 0
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 0
# - End internal simulation -
# 7 paying tribute to 0
# - Begin internal simulation -
# War between 9 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 8
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 7
# - End internal simulation -
# - Begin internal simulation -
# 9 paying tribute to 8
# - End internal simulation -
# 9 paying tribute to 8
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 0
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 0
# - End internal simulation -
# 9 paying tribute to 0
# - Begin internal simulation -
# 5 paying tribute to 1
# - End internal simulation -
# 5 paying tribute to 1
# - Begin internal simulation -
# 3 paying tribute to 4
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 4
# - End internal simulation -
# 3 paying tribute to 4
# *	*	*
# - Begin internal simulation -
# War between 9 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 8
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 7
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 1
# - End internal simulation -
# 5 paying tribute to 1
# - Begin internal simulation -
# War between 7 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 9
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 6
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# War between 9 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 8
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 7
# - End internal simulation -
# - Begin internal simulation -
# 3 paying tribute to 4
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 4
# - End internal simulation -
# 3 paying tribute to 4
# - Begin internal simulation -
# 5 paying tribute to 1
# - End internal simulation -
# 5 paying tribute to 1
# *	*	*
# - Begin internal simulation -
# War between 9 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 8
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 7
# - End internal simulation -
# - Begin internal simulation -
# War between 2 and 3
# - End internal simulation -
# - Begin internal simulation -
# War between 5 and 1
# - End internal simulation -
# - Begin internal simulation -
# War between 5 and 4
# - End internal simulation -
# - Begin internal simulation -
# War between 5 and 6
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 8
# - End internal simulation -
# 9 paying tribute to 8
# - Begin internal simulation -
# War between 2 and 3
# - End internal simulation -
# - Begin internal simulation -
# 2 paying tribute to 3
# - End internal simulation -
# - Begin internal simulation -
# 4 paying tribute to 3
# - End internal simulation -
# 2 paying tribute to 3
# *	*	*
# - Begin internal simulation -
# 3 paying tribute to 4
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 4
# - End internal simulation -
# 3 paying tribute to 4
# - Begin internal simulation -
# 5 paying tribute to 6
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 6
# - End internal simulation -
# 7 paying tribute to 6
# - Begin internal simulation -
# War between 7 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 9
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 6
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# 5 paying tribute to 1
# - End internal simulation -
# 5 paying tribute to 1
# - Begin internal simulation -
# War between 2 and 3
# - End internal simulation -
# - Begin internal simulation -
# 3 paying tribute to 4
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 4
# - End internal simulation -
# 3 paying tribute to 4
# *	*	*
# - Begin internal simulation -
# War between 9 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 8
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 7
# - End internal simulation -
# - Begin internal simulation -
# War between 2 and 3
# - End internal simulation -
# - Begin internal simulation -
# 2 paying tribute to 3
# - End internal simulation -
# - Begin internal simulation -
# 4 paying tribute to 3
# - End internal simulation -
# 2 paying tribute to 3
# *	*	*
# - Begin internal simulation -
# War between 9 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 8
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 7
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 6
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 6
# - End internal simulation -
# 7 paying tribute to 6
# *	*	*
# - Begin internal simulation -
# 5 paying tribute to 1
# - End internal simulation -
# 5 paying tribute to 1
# - Begin internal simulation -
# 2 paying tribute to 3
# - End internal simulation -
# - Begin internal simulation -
# 4 paying tribute to 3
# - End internal simulation -
# 2 paying tribute to 3
# - Begin internal simulation -
# 3 paying tribute to 4
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 4
# - End internal simulation -
# 3 paying tribute to 4
# *	*	*
# - Begin internal simulation -
# 5 paying tribute to 1
# - End internal simulation -
# 5 paying tribute to 1
# - Begin internal simulation -
# 3 paying tribute to 4
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 4
# - End internal simulation -
# 3 paying tribute to 4
# *	*	*
# - Begin internal simulation -
# War between 2 and 3
# - End internal simulation -
# - Begin internal simulation -
# 3 paying tribute to 4
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 4
# - End internal simulation -
# 3 paying tribute to 4
# - Begin internal simulation -
# 5 paying tribute to 6
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 6
# - End internal simulation -
# 7 paying tribute to 6
# *	*	*
# - Begin internal simulation -
# 5 paying tribute to 1
# - End internal simulation -
# 5 paying tribute to 1
# - Begin internal simulation -
# War between 2 and 3
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 8
# - End internal simulation -
# 9 paying tribute to 8
# - Begin internal simulation -
# War between 2 and 3
# - End internal simulation -
# - Begin internal simulation -
# 2 paying tribute to 3
# - End internal simulation -
# - Begin internal simulation -
# 4 paying tribute to 3
# - End internal simulation -
# 2 paying tribute to 3
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 0
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 0
# - End internal simulation -
# 9 paying tribute to 0
# - Begin internal simulation -
# War between 2 and 3
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 9
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 6
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# 5 paying tribute to 1
# - End internal simulation -
# 5 paying tribute to 1
# - Begin internal simulation -
# 3 paying tribute to 4
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 4
# - End internal simulation -
# 3 paying tribute to 4
# - Begin internal simulation -
# War between 7 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 9
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 6
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 8
# - End internal simulation -
# 9 paying tribute to 8
# - Begin internal simulation -
# 5 paying tribute to 6
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 6
# - End internal simulation -
# 7 paying tribute to 6
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 8
# - End internal simulation -
# 9 paying tribute to 8
# - Begin internal simulation -
# 9 paying tribute to 0
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 0
# - End internal simulation -
# 7 paying tribute to 0
# - Begin internal simulation -
# 5 paying tribute to 6
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 6
# - End internal simulation -
# 5 paying tribute to 6
# *	*	*
# - Begin internal simulation -
# War between 2 and 3
# - End internal simulation -
# - Begin internal simulation -
# 3 paying tribute to 4
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 4
# - End internal simulation -
# 3 paying tribute to 4
# - Begin internal simulation -
# War between 5 and 1
# - End internal simulation -
# - Begin internal simulation -
# War between 5 and 4
# - End internal simulation -
# - Begin internal simulation -
# War between 5 and 6
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# War between 9 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 8
# - End internal simulation -
# - Begin internal simulation -
# War between 9 and 7
# - End internal simulation -
# - Begin internal simulation -
# War between 2 and 3
# - End internal simulation -
# - Begin internal simulation -
# 3 paying tribute to 4
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 4
# - End internal simulation -
# 3 paying tribute to 4
# *	*	*
# - Begin internal simulation -
# 5 paying tribute to 1
# - End internal simulation -
# 5 paying tribute to 1
# - Begin internal simulation -
# 2 paying tribute to 3
# - End internal simulation -
# - Begin internal simulation -
# 4 paying tribute to 3
# - End internal simulation -
# 2 paying tribute to 3
# - Begin internal simulation -
# War between 7 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 9
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 6
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 0
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 0
# - End internal simulation -
# 9 paying tribute to 0
# - Begin internal simulation -
# 5 paying tribute to 1
# - End internal simulation -
# 5 paying tribute to 1
# - Begin internal simulation -
# War between 7 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 9
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 6
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 0
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 0
# - End internal simulation -
# 7 paying tribute to 0
# - Begin internal simulation -
# 5 paying tribute to 6
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 6
# - End internal simulation -
# 5 paying tribute to 6
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 8
# - End internal simulation -
# 9 paying tribute to 8
# - Begin internal simulation -
# 5 paying tribute to 1
# - End internal simulation -
# 5 paying tribute to 1
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 8
# - End internal simulation -
# 9 paying tribute to 8
# - Begin internal simulation -
# War between 2 and 3
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 0
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 9
# - End internal simulation -
# - Begin internal simulation -
# War between 7 and 6
# - End internal simulation -
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 0
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 0
# - End internal simulation -
# 7 paying tribute to 0
# - Begin internal simulation -
# 5 paying tribute to 1
# - End internal simulation -
# 5 paying tribute to 1
# - Begin internal simulation -
# 2 paying tribute to 3
# - End internal simulation -
# - Begin internal simulation -
# 4 paying tribute to 3
# - End internal simulation -
# 2 paying tribute to 3
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 0
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 0
# - End internal simulation -
# 9 paying tribute to 0
# - Begin internal simulation -
# 2 paying tribute to 3
# - End internal simulation -
# - Begin internal simulation -
# 4 paying tribute to 3
# - End internal simulation -
# 2 paying tribute to 3
# - Begin internal simulation -
# 5 paying tribute to 6
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 6
# - End internal simulation -
# 5 paying tribute to 6
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 8
# - End internal simulation -
# 9 paying tribute to 8
# - Begin internal simulation -
# 9 paying tribute to 0
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 0
# - End internal simulation -
# 7 paying tribute to 0
# - Begin internal simulation -
# 3 paying tribute to 4
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 4
# - End internal simulation -
# 3 paying tribute to 4
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 8
# - End internal simulation -
# 9 paying tribute to 8
# - Begin internal simulation -
# 9 paying tribute to 0
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 0
# - End internal simulation -
# 7 paying tribute to 0
# - Begin internal simulation -
# 3 paying tribute to 4
# - End internal simulation -
# - Begin internal simulation -
# 5 paying tribute to 4
# - End internal simulation -
# 3 paying tribute to 4
# *	*	*
# - Begin internal simulation -
# 9 paying tribute to 0
# - End internal simulation -
# - Begin internal simulation -
# 7 paying tribute to 0
# - End internal simulation -
# 9 paying tribute to 0
# - Begin internal simulation -
# War between 2 and 3
# - End internal simulation -
# - Begin internal simulation -
# War between 5 and 1
# - End internal simulation -
# - Begin internal simulation -
# War between 5 and 4
# - End internal simulation -
# - Begin internal simulation -
# War between 5 and 6
# - End internal simulation -
# *	*	*

# %%
nx.draw(m.graph, pos=pos, node_size=[m.agents[i].wealth for i in m.agents])

# %%
plt.plot(m.war_series)

# %%
for s in m.agent_wealth_series.values():
    plt.plot(s)
