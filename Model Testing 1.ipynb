# %%
from TributeModel import Model

import json
import random

import networkx as nx
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
#G = nx.grid_2d_graph(10,10)
G = nx.watts_strogatz_graph(10, 3, 0.2)
#G = nx.scale_free_graph(10)
#G = G.to_undirected()
#G = nx.erdos_renyi_graph(10, 1)

G = nx.relabel_nodes(G, {tup: i for i, tup in enumerate(G.nodes())})
m = Model(G)
m.verbose = False
m.heuristic = True
m.random_execution = False
m.tribute = 100
m.max_depth = 2
#m.actions_per_turn = 10
pos = nx.spring_layout(G)

# %%
for agent in m.agents.values():
    agent.max_depth = 0

# %%
#m.verbose = False
for i in range(300):
    m.step()
    #print i
    #print "*\t*\t*"
    if (i % 50) == 0:
        print i
# Out:
# 0
# 50
# 100
# 150
# 200
# 250

# %%
nx.draw(m.graph, pos=pos, node_size=[m.agents[i].wealth for i in m.agents])

# %%
fig = m.plot(plt.figure(figsize=(12,4)))

# %%
plt.hist(m.war_scale, bins=26)
# Out:
# (array([66,  4,  1,  1,  0,  2,  0,  2,  2,  2,  5,  0,  0,  0,  0,  2,  1,
#          1,  2,  1,  0,  3,  2,  3,  3,  3]),
#  array([  5.77567808e-03,   4.21755084e-01,   8.37734490e-01,
#           1.25371390e+00,   1.66969330e+00,   2.08567271e+00,
#           2.50165211e+00,   2.91763152e+00,   3.33361093e+00,
#           3.74959033e+00,   4.16556974e+00,   4.58154914e+00,
#           4.99752855e+00,   5.41350796e+00,   5.82948736e+00,
#           6.24546677e+00,   6.66144617e+00,   7.07742558e+00,
#           7.49340499e+00,   7.90938439e+00,   8.32536380e+00,
#           8.74134320e+00,   9.15732261e+00,   9.57330202e+00,
#           9.98928142e+00,   1.04052608e+01,   1.08212402e+01]),
#  <a list of 26 Patch objects>)

# %%
out = m.to_dict()

# %%
with open("test.json", "wb") as f:
    json.dump(out, f)

# %%
for agent, agent_data in out["agents"].items():
    print agent, agent_data["max_depth"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-1a1f440ffdf1> in <module>()
# ----> 1 for agent, agent_data in out["agents"].items():
#       2     print agent, agent_data["max_depth"]
#
# NameError: name 'out' is not defined
