# %%
from TributeModel import Model

import json

import networkx as nx
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
#G = nx.grid_2d_graph(10,10)
G = nx.watts_strogatz_graph(10, 3, 0.2)
#G = nx.scale_free_graph(10)
#G = G.to_undirected()
#G = nx.erdos_renyi_graph(10, 1)

G = nx.relabel_nodes(G, {tup: i for i, tup in enumerate(G.nodes())})
m = Model(G)
m.verbose = True
m.random_execution = False
m.tribute = 100
#m.actions_per_turn = 10
pos = nx.spring_layout(G)

# %%
for agent in m.agents.values():
    agent.max_depth = 2

# %%
#m.verbose = False
for i in range(30):
    m.step()
    #print "*\t*\t*"
    if (i % 30) == 0:
        print i
# Out:
#  6 active
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 6 and 4
# 	4 -272 -124.5
# 	War between 6 and 4
# 	8 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 8 and 9
# 		9 -229 -204.0
# 		War between 8 and 9
# 	8 taking no action.
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 6 and 5
# 	5 -331 -163.75
# 	War between 6 and 5
# 	8 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 8 and 9
# 		9 -229 -204.0
# 		War between 8 and 9
# 	8 taking no action.
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 6 and 7
# 	7 -366 -207.5
# 	War between 6 and 7
# 	8 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 8 and 9
# 		9 -229 -204.0
# 		War between 8 and 9
# 	8 taking no action.
#  6 taking no action.
# 0
#  8 active
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 8 and 9
# 	9 -229 -209.0
# 	War between 8 and 9
# 	1 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 1 and 4
# 		4 -208 -177.5
# 		War between 1 and 4
# 	1 threatening 4
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 1 and 4
# 	4 -208 -177.5
# 	War between 1 and 4
#  8 taking no action.
#  1 active
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 1 and 4
# 	4 -208 -177.5
# 	War between 1 and 4
# 	9 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 9 and 0
# 		0 -71 -32.25
# 		War between 9 and 0
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 9 and 8
# 		8 -213 -16.25
# 		War between 9 and 8
# 	9 taking no action.
#  1 threatening 4
#  Spawning new model at depth 1
# 	9 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 9 and 0
# 		0 -71 -32.25
# 		War between 9 and 0
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 9 and 8
# 		8 -213 -16.25
# 		War between 9 and 8
# 	9 taking no action.
#  Spawning new model at depth 1
# 	War between 1 and 4
# 	9 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 9 and 0
# 		0 -71 -32.25
# 		War between 9 and 0
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 9 and 8
# 		8 -213 -16.25
# 		War between 9 and 8
# 	9 taking no action.
#  4 -208 -177.5
#  War between 1 and 4
#  9 active
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 9 and 0
# 	0 -71 -32.25
# 	War between 9 and 0
# 	3 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 3 and 0
# 		0 -232.25 -40.3125
# 		War between 3 and 0
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 3 and 2
# 		2 -227 -33.75
# 		War between 3 and 2
# 	Spawning new model at depth
# 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 3 and 4
# 		4 -302.5 -280.25
# 		War between 3 and 4
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 3 and 7
# 		7 -291 -268.75
# 		War between 3 and 7
# 	3 taking no action.
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 9 and 8
# 	8 -213 -16.25
# 	War between 9 and 8
# 	3 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 3 and 0
# 		0 -149 63.75
# 		War between 3 and 0
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 3 and 2
# 		2 -227 -33.75
# 		War between 3 and 2
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 3 and 4
# 		4 -302.5 -280.25
# 		War between 3 and 4
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 3 and 7
# 		7 -291 -268.75
# 		War between 3 and 7
# 	3 taking no action.
#  9 taking no action.
#  3 active
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 3 and 0
# 	0 -149 21.25
# 	War between 3 and 0
# 	5 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 5 and 6
# 		6 -69 72.25
# 		War between 5 and 6
# 	5 taking no action.
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 3 and 2
# 	2 -227 -33.75
# 	War between 3 and 2
# 	5 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 5 and 6
# 		6 -69 72.25
# 		War between 5 and 6
# 	5 taking no action.
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 3 and 4
# 	4 -302.5 -285.25
# 	War between 3 and 4
# 	5 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 5 and 6
# 		6 -69 72.25
# 		War between 5 and 6
# 	5 taking no action.
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 3 and 7
# 	7 -291 -273.75
# 	War between 3 and 7
# 	5 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 5 and 6
# 		6 -69 83.75
# 		War between 5 and 6
# 	5 taking no action.
#  3 taking no action.
#  5 active
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 5 and 6
# 	6 -69 72.25
# 	War between 5 and 6
# 	2 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 2 and 3
# 		3 -173 -152.0
# 		War between 2 and 3
# 	2 taking no action.
#  5 taking no action.
#  2 active
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 2 and 3
# 	3 -173 -152.0
# 	War between 2 and 3
# 	7 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 7 and 3
# 		3 -252.0 -237.0
# 		War between 7 and 3
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 7 and 6
# 		6 -34 46.0
# 		War between 7 and 6
# 	7 taking no action.
#  2 taking no action.
#  7 active
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 7 and 3
# 	3 -151 -141.0
# 	War between 7 and 3
# 	0 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 0 and 9
# 		9 -329 -161.25
# 		War between 0 and 9
# 	Spawning new model at depth 2
# Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 0 and 3
# 		3 -341.0 -188.5
# 		War between 0 and 3
# 	0 taking no action.
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 7 and 6
# 	6 -34 41.0
# 	War between 7 and 6
# 	0 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 0 and 9
# 		9 -329 -161.25
# 		War between 0 and 9
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 0 and 3
# 		3 -251 -98.5
# 		War between 0 and 3
# 	0 taking no action.
#  7 taking no action.
#  0 active
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 0 and 9
# 	9 -329 -161.25
# 	War between 0 and 9
# 	4 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 4 and 1
# 		1 -190.0 12.5
# 		War between 4 and 1
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 4 and 3
# 		3 -97.5 -60.125
# 		War between 4 and 3
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 4 and 6
# 		6 -22.5 43.875
# 		War between 4 and 6
# 	4 taking no action.
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 0 and 3
# 	3 -251 -98.5
# 	War between 0 and 3
# 	4 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 4 and 1
# 		1 -190.0 12.5
# 		War between 4 and 1
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 4 and 3
# 		3 -223.0 -185.625
# 		War between 4 and 3
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 4 and 6
# 		6 -22.5 43.875
# 		War between 4 and 6
# 	4 taking no action.
#  0 taking no action.
#  4 active
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 4 and 1
# 	1 -190.0 12.5
# 	War between 4 and 1
# 	6 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 6 and 4
# 		4 -467.125 -333.90625
# 		War between 6 and 4
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 6 and 5
# 		5 -331 -163.75
# 		War between 6 and 5
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 6 and 7
# 		7 -366 -222.5
# 		War between 6 and 7
# 	6 taking no action.
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 4 and 3
# 	3 -151 -138.125
# 	War between 4 and 3
# 	6 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 6 and 4
# 		4 -490.25 -362.8125
# 		War between 6 and 4
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 6 and 5
# 		5 -331 -163.75
# 		War between 6 and 5
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 6 and 7
# 		7 -366 -207.5
# 		War between 6 and 7
# 	6 taking no action.
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 4 and 6
# 	6 -22.5 43.875
# 	War between 4 and 6
# 	6 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 6 and 4
# 		4 -421.875 -343.71875
# 		War between 6 and 4
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 6 and 5
# 		5 -243.875 -54.84375
# 		War between 6 and 5
# 	Spawning new model at depth 2
# Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 6 and 7
# 		7 -278.875 -200.71875
# 		War between 6 and 7
# 	6 taking no action.
#  4 taking no action.
#  6 active
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 6 and 4
# 	4 -377.5 -239.0
# 	War between 6 and 4
# 	8 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 8 and 9
# 		9 -229 -224.0
# 		War between 8 and 9
# 	8 taking no action.
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 6 and 5
# 	5 -331 -163.75
# 	War between 6 and 5
# 	8 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 8 and 9
# 		9 -229 -224.0
# 		War between 8 and 9
# 	8 taking no action.
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 6 and 7
# 	7 -366 -227.5
# 	War between 6 and 7
# 	8 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 8 and 9
# 		9 -229 -224.0
# 		War between 8 and 9
# 	8 taking no action.
#  6 taking no action.
#  8 active
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 8 and 9
# 	9 -229 -224.0
# 	War between 8 and 9
# 	1 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 1 and 4
# 		4 -277.5 -272.125
# 		War between 1 and 4
# 	1 threatening 4
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 1 and 4
# 	4 -277.5 -272.125
# 	War between 1 and 4
#  8 taking no action.
#  1 active
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 1 and 4
# 	4 -277.5 -272.125
# 	War between 1 and 4
# 	9 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 9 and 0
# 		0 -71 -47.25
# 		War between 9 and 0
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 9 and 8
# 		8 -213 -16.25
# 		War between 9 and 8
# 	9 taking no action.
#  1 threatening 4
#  Spawning new model at depth 1
# 	9 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 9 and 0
# 		0 -71 -47.25
# 		War between 9 and 0
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 9 and 8
# 		8 -213 -16.25
# 		War between 9 and 8
# 	9 taking no action.
#  Spawning new model at depth 1
# 	War between 1 and 4
# 	9 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 9 and 0
# 		0 -71 -47.25
# 		War between 9 and 0
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 9 and 8
# 		8 -213 -16.25
# 		War between 9 and 8
# 	9 taking no action.
#  4 -277.5 -272.125
#  War between 1 and 4
#  9 active
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 9 and 0
# 	0 -71 -52.25
# 	War between 9 and 0
# 	3 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 3 and 0
# 		0 -252.25 -65.3125
# 		War between 3 and 0
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 3 and 2
# 		2 -227 -33.75
# 		War between 3 and 2
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 3 and 4
# 		4 -397.125 -394.875
# 		War between 3 and 4
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 3 and 7
# 		7 -291 -288.75
# 		War between 3 and 7
# 	3 taking no action.
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 9 and 8
# 	8 -213 -16.25
# 	War between 9 and 8
# 	3 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 3 and 0
# 		0 -149 63.75
# 		War between 3 and 0
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 3 and 2
# 		2 -227 -33.75
# 		War between 3 and 2
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 3 and 4
# 		4 -397.125 -394.875
# 		War between 3 and 4
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 3 and 7
# 		7 -291 -288.75
# 		War between 3 and 7
# 	3 taking no action.
#  9 taking no action.
#  3 active
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 3 and 0
# 	0 -149 6.25
# 	War between 3 and 0
# 	5 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 5 and 6
# 		6 -69 57.25
# 		War between 5 and 6
# 	5 taking no action.
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 3 and 2
# 	2 -227 -33.75
# 	War between 3 and 2
# 	5 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 5 and 6
# 		6 -69 57.25
# 		War between 5 and 6
# 	5 taking no action.
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 3 and 4
# 	4 -397.125 -394.875
# 	War between 3 and 4
# 	5 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 5 and 6
# 		6 -69 57.25
# 		War between 5 and 6
# 	5 taking no action.
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 3 and 7
# 	7 -291 -288.75
# 	War between 3 and 7
# 	5 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 5 and 6
# 		6 -69 163.375
# 		War between 5 and 6
# 	5 taking no action.
#  3 taking no action.
#  5 active
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 5 and 6
# 	6 -69 57.25
# 	War between 5 and 6
# 	2 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 2 and 3
# 		3 -173 -167.0
# 		War between 2 and 3
# 	2 taking no action.
#  5 taking no action.
#  2 active
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 2 and 3
# 	3 -173 -172.0
# 	War between 2 and 3
# 	7 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 7 and 3
# 		3 -272.0 -277.0
# 		3 paying tribute to 7
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 7 and 6
# 		6 -34 26.0
# 		War between 7 and 6
# 	7 threatening 3
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 7 and 3
# 	3 -272.0 -277.0
# 	3 paying tribute to 7
#  2 threatening 3
#  Spawning new model at depth 1
# 	7 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 7 and 3
# 		3 -273 -278.0
# 		3 paying tribute to 7
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 7 and 6
# 		6 -34 26.0
# 		War between 7 and 6
# 	7 threatening 3
# Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 7 and 3
# 	3 -273 -278.0
# 	3 paying tribute to 7
#  Spawning new model at depth 1
# 	War between 2 and 3
# 	7 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 7 and 3
# 		3 -272.0 -277.0
# 		3 paying tribute to 7
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 7 and 6
# 		6 -34 26.0
# 		War between 7 and 6
# 	7 threatening 3
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 7 and 3
# 	3 -272.0 -277.0
# 	3 paying tribute to 7
#  3 -273 -272.0
#  War between 2 and 3
#  7 active
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 7 and 3
# 	3 -272.0 -277.0
# 	3 paying tribute to 7
# 	0 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 0 and 9
# 		9 -329 -161.25
# 		War between 0 and 9
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 0 and 3
# 		3 -472.0 -370.5
# 		War between 0 and 3
# 	0 threatening 9
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 0 and 9
# 	9 -329 -161.25
# 	War between 0 and 9
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 7 and 6
# 	6 -34 26.0
# 	War between 7 and 6
# 	0 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 0 and 9
# 		9 -329 -161.25
# 		War between 0 and 9
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 0 and 3
# 		3 -372.0 -215.0
# 		War between 0 and 3
# 	0 taking no action.
#  7 threatening 3
#  Spawning new model at depth 1
# 	0 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 0 and 9
# 		9 -329 -161.25
# 		War between 0 and 9
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 0 and 3
# 		3 -472.0 -370.5
# 		War between 0 and 3
# 	0 threatening 9
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 0 and 9
# 	9 -329 -161.25
# 	War between 0 and 9
#  Spawning new model at depth 1
# 	War between 7 and 3
# 	0 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 0 and 9
# 		9 -329 -161.25
# 		War between 0 and 9
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 0 and 3
# 		3 -477.0 -346.25
# 		War between 0 and 3
# 	0 threatening 9
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 0 and 9
# 	9 -329 -161.25
# 	War between 0 and 9
#  3 -230.0 -168.75
#  War between 7 and 3
#  0 active
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 0 and 9
# 	9 -329 -161.25
# 	War between 0 and 9
# 	4 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 4 and 1
# 		1 -187.5 15.625
# 		War between 4 and 1
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 4 and 3
# 		3 -268.75 -247.21875
# 		War between 4 and 3
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 4 and 6
# 		6 31 52.53125
# 		War between 4 and 6
# 	4 taking no action.
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 0 and 3
# 	3 -477.0 -346.25
# 	War between 0 and 3
# 	4 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 4 and 1
# 		1 -187.5 15.625
# 		War between 4 and 1
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 4 and 3
# 		3 -446.25 -424.71875
# 		War between 4 and 3
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 4 and 6
# 		6 31 52.53125
# 		War between 4 and 6
# 	4 taking no action.
#  0 threatening 9
#  Spawning new model at depth 1
# 	4 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 4 and 1
# 		1 -187.5 15.625
# 		War between 4 and 1
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 4 and 3
# 		3 -477.0 -455.46875
# 		War between 4 and 3
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 4 and 6
# 		6 31 52.53125
# 		War between 4 and 6
# 	4 taking no action.
#  Spawning new model at depth 1
# 	War between 0 and 9
# 	4 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 4 and 1
# 		1 -187.5 15.625
# 		War between 4 and 1
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 4 and 3
# 		3 -268.75 -247.21875
# 		War between 4 and 3
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 4 and 6
# 		6 31 52.53125
# 		War between 4 and 6
# 	4 taking no action.
#  9 -329 -161.25
#  War between 0 and 9
#  4 active
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 4 and 1
# 	1 -187.5 15.625
# 	War between 4 and 1
# 	6 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 6 and 4
# 		4 -558.71875 -448.3984375
# 		War between 6 and 4
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 6 and 5
# 		5 -331 -163.75
# 		War between 6 and 5
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 6 and 7
# 		7 -463.5 -329.375
# 		War between 6 and 7
# 	6 threatening 5
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 6 and 5
# 	5 -331 -163.75
# 	War between 6 and 5
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 4 and 3
# 	3 -268.75 -252.21875
# 	War between 4 and 3
# 	6 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 6 and 4
# 		4 -548.375 -435.46875
# 		War between 6 and 4
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 6 and 5
# 		5 -331 -163.75
# 		War between 6 and 5
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 6 and 7
# 		7 -463.5 -329.375
# 		War between 6 and 7
# 	6 threatening 5
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 6 and 5
# 	5 -331 -163.75
# 	War between 6 and 5
#  Spawning new model at depth 1
# Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 4 and 6
# 	6 31 47.53125
# 	War between 4 and 6
# 	6 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 6 and 4
# 		4 -540.15625 -425.1953125
# 		War between 6 and 4
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 6 and 5
# 		5 -247.53125 -59.4140625
# 		War between 6 and 5
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 6 and 7
# 		7 -380.03125 -225.0390625
# 		War between 6 and 7
# 	6 threatening 5
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 6 and 5
# 	5 -247.53125 -59.4140625
# 	War between 6 and 5
#  4 threatening 6
#  Spawning new model at depth 1
# 	6 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 6 and 4
# 		4 -272.125 -90.15625
# 		War between 6 and 4
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 6 and 5
# 		5 -231 -38.75
# 		War between 6 and 5
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 6 and 7
# 		7 -363.5 -204.375
# 		War between 6 and 7
# 	6 taking no action.
#  Spawning new model at depth 1
# 	War between 4 and 6
# 	6 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 6 and 4
# 		4 -540.15625 -425.1953125
# 		War between 6 and 4
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 6 and 5
# 		5 -247.53125 -59.4140625
# 		War between 6 and 5
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 6 and 7
# 		7 -380.03125 -225.0390625
# 		War between 6 and 7
# 	6 threatening 5
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 6 and 5
# 	5 -247.53125 -59.4140625
# 	War between 6 and 5
#  6 31 59.4140625
#  War between 4 and 6
#  6 active
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 6 and 4
# 	4 -540.15625 -425.1953125
# 	War between 6 and 4
# 	8 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 8 and 9
# 		9 -327.5 -271.25
# 		War between 8 and 9
# 	8 threatening 9
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 8 and 9
# 	9 -327.5 -271.25
# 	War between 8 and 9
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 6 and 5
# 	5 -247.53125 -59.4140625
# 	War between 6 and 5
# 	8 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 8 and 9
# 		9 -327.5 -271.25
# 		War between 8 and 9
# 	8 threatening 9
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 8 and 9
# 	9 -327.5 -271.25
# 	War between 8 and 9
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 6 and 7
# 	7 -380.03125 -225.0390625
# 	War between 6 and 7
# 	8 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 8 and 9
# 		9 -327.5 -271.25
# 		War between 8 and 9
# 	8 threatening 9
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 8 and 9
# 	9 -327.5 -271.25
# 	War between 8 and 9
#  6 threatening 5
#  Spawning new model at depth 1
# 	8 active
# Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 8 and 9
# 		9 -327.5 -271.25
# 		War between 8 and 9
# 	8 threatening 9
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 8 and 9
# 	9 -327.5 -271.25
# 	War between 8 and 9
#  Spawning new model at depth 1
# 	War between 6 and 5
# 	8 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 8 and 9
# 		9 -327.5 -271.25
# 		War between 8 and 9
# 	8 threatening 9
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 8 and 9
# 	9 -327.5 -271.25
# 	War between 8 and 9
#  5 -247.53125 -59.4140625
#  War between 6 and 5
#  8 active
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 8 and 9
# 	9 -327.5 -271.25
# 	War between 8 and 9
# 	1 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 1 and 4
# 		4 -364.0 -308.0
# 		War between 1 and 4
# 	1 threatening 4
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 1 and 4
# 	4 -364.0 -308.0
# 	War between 1 and 4
#  8 threatening 9
#  Spawning new model at depth 1
# 	1 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 1 and 4
# 		4 -364.0 -308.0
# 		War between 1 and 4
# 	1 threatening 4
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 1 and 4
# 	4 -364.0 -308.0
# 	War between 1 and 4
#  Spawning new model at depth 1
# 	War between 8 and 9
# 	1 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 1 and 4
# 		4 -364.0 -308.0
# 		War between 1 and 4
# 	1 threatening 4
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 1 and 4
# 	4 -364.0 -308.0
# 	War between 1 and 4
#  9 -327.5 -271.25
#  War between 8 and 9
#  1 active
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 1 and 4
# 	4 -364.0 -313.0
# 	War between 1 and 4
# 	9 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 9 and 0
# 		0 68.75 113.125
# 		War between 9 and 0
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 9 and 8
# 		8 -40.625 199.21875
# 		War between 9 and 8
# 	9 taking no action.
#  1 threatening 4
#  Spawning new model at depth 1
# 	9 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 9 and 0
# 		0 68.75 113.125
# 		War between 9 and 0
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 9 and 8
# 		8 -40.625 199.21875
# 		War between 9 and 8
# 	9 taking no action.
#  Spawning new model at depth 1
# 	War between 1 and 4
# 	9 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 9 and 0
# 		0 68.75 113.125
# 		War between 9 and 0
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 9 and 8
# 		8 -40.625 199.21875
# 		War between 9 and 8
# 	9 taking no action.
#  4 -364.0 -313.0
#  War between 1 and 4
#  9 active
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 9 and 0
# 	0 68.75 113.125
# 	War between 9 and 0
# 	3 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# Spawning new model at depth 3
# 			War between 3 and 0
# 		0 -86.875 141.40625
# 		War between 3 and 0
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 3 and 2
# 		2 -128.75 89.0625
# 		War between 3 and 2
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 3 and 4
# 		4 -414.21875 -394.25
# 		War between 3 and 4
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 3 and 7
# 		7 -162.5 -142.53125
# 		War between 3 and 7
# 	3 taking no action.
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 9 and 8
# 	8 -40.625 199.21875
# 	War between 9 and 8
# 	3 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 3 and 0
# 		0 -31.25 210.9375
# 		War between 3 and 0
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 3 and 2
# 		2 -128.75 89.0625
# 		War between 3 and 2
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 3 and 4
# 		4 -414.21875 -394.25
# 		War between 3 and 4
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 3 and 7
# 		7 -162.5 -142.53125
# 		War between 3 and 7
# 	3 taking no action.
#  9 taking no action.
#  3 active
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 3 and 0
# 	0 -31.25 190.0
# 	War between 3 and 0
# 	5 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 5 and 6
# 		6 -140.5859375 -29.810546875
# 		War between 5 and 6
# 	5 taking no action.
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 3 and 2
# 	2 -128.75 89.0625
# 	War between 3 and 2
# 	5 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 5 and 6
# 		6 -140.5859375 -29.810546875
# 		War between 5 and 6
# 	5 taking no action.
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 3 and 4
# 	4 -414.21875 -394.25
# 	War between 3 and 4
# 	5 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 5 and 6
# 		6 -140.5859375 -29.810546875
# 		War between 5 and 6
# 	5 taking no action.
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 3 and 7
# 	7 -162.5 -142.53125
# 	War between 3 and 7
# 	5 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 5 and 6
# 		6 -140.5859375 51.439453125
# 		War between 5 and 6
# 	5 taking no action.
#  3 taking no action.
#  5 active
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 5 and 6
# 	6 -140.5859375 -34.810546875
# 	War between 5 and 6
# 	2 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 2 and 3
# 		3 -271.25 -272.8125
# 		3 paying tribute to 2
# 	2 threatening 3
# 	Spawning new model at depth 2
# Spawning new model at depth 2
# 		War between 2 and 3
# 	3 -271.25 -272.8125
# 	3 paying tribute to 2
#  5 taking no action.
#  2 active
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 2 and 3
# 	3 -271.25 -272.8125
# 	3 paying tribute to 2
# 	7 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 7 and 3
# 		3 -371.25 -366.875
# 		War between 7 and 3
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 7 and 6
# 		6 -138.71875 -36.2109375
# 		War between 7 and 6
# 	7 taking no action.
#  2 threatening 3
#  Spawning new model at depth 1
# 	7 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 7 and 3
# 		3 -371.25 -366.875
# 		War between 7 and 3
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 7 and 6
# 		6 -138.71875 -36.2109375
# 		War between 7 and 6
# 	7 taking no action.
#  Spawning new model at depth 1
# 	War between 2 and 3
# 	7 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 7 and 3
# 		3 -372.8125 -368.4375
# 		War between 7 and 3
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 7 and 6
# 		6 -138.71875 -36.2109375
# 		War between 7 and 6
# 	7 taking no action.
#  3 -271.25 -272.8125
#  3 paying tribute to 2
#  7 active
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 7 and 3
# 	3 -371.25 -366.875
# 	War between 7 and 3
# 	0 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 0 and 9
# 		9 -471.25 -339.0625
# 		War between 0 and 9
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 0 and 3
# 		3 -564.375 -495.3125
# 		War between 0 and 3
# 	0 threatening 9
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 0 and 9
# 	9 -471.25 -339.0625
# 	War between 0 and 9
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 7 and 6
# 	6 -138.71875 -36.2109375
# 	War between 7 and 6
# 	0 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 0 and 9
# 		9 -471.25 -339.0625
# 		War between 0 and 9
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 0 and 3
# 		3 -468.75 -399.6875
# 		War between 0 and 3
# 	0 taking no action.
#  7 taking no action.
#  0 active
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 0 and 9
# 	9 -471.25 -339.0625
# 	War between 0 and 9
# 	4 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 4 and 1
# 		1 5.0 256.25
# 		War between 4 and 1
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 4 and 3
# 		3 -371.25 -308.9453125
# 		War between 4 and 3
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 4 and 6
# 		6 -40.5859375 21.71875
# 		War between 4 and 6
# 	4 taking no action.
#  Spawning new model at depth 1
# Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 0 and 3
# 	3 -468.75 -404.6875
# 	War between 0 and 3
# 	4 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 4 and 1
# 		1 5.0 256.25
# 		War between 4 and 1
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 4 and 3
# 		3 -504.6875 -442.3828125
# 		War between 4 and 3
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 4 and 6
# 		6 -40.5859375 21.71875
# 		War between 4 and 6
# 	4 taking no action.
#  0 taking no action.
#  4 active
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 4 and 1
# 	1 5.0 256.25
# 	War between 4 and 1
# 	6 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 6 and 4
# 		4 -525.6171875 -448.322265625
# 		War between 6 and 4
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 6 and 5
# 		5 -259.4140625 -74.267578125
# 		War between 6 and 5
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 6 and 7
# 		7 -261.28125 -76.6015625
# 		War between 6 and 7
# 	6 taking no action.
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 4 and 3
# 	3 -371.25 -308.9453125
# 	War between 4 and 3
# 	6 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 6 and 4
# 		4 -548.3125 -442.6484375
# 		War between 6 and 4
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 6 and 5
# 		5 -259.4140625 -74.267578125
# 		War between 6 and 5
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 6 and 7
# 		7 -261.28125 -76.6015625
# 		War between 6 and 7
# 	6 taking no action.
#  Spawning new model at depth 1
# 	Spawning new model at depth 2
# 	Spawning new model at depth 2
# 		War between 4 and 6
# 	6 -40.5859375 21.71875
# 	War between 4 and 6
# 	6 active
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 6 and 4
# 		4 -460.921875 -417.376953125
# 		War between 6 and 4
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 6 and 5
# 		5 -221.71875 -27.1484375
# 		War between 6 and 5
# 	Spawning new model at depth 2
# 		Spawning new model at depth 3
# 		Spawning new model at depth 3
# 			War between 6 and 7
# 		7 -223.5859375 -29.482421875
# 		War between 6 and 7
# 	6 taking no action.
#  4 taking no action.

# %%
nx.draw(m.graph, pos=pos, node_size=[m.agents[i].wealth for i in m.agents])

# %%
fig = m.plot(plt.figure(figsize=(12,4)))

# %%
plt.hist(m.war_scale, bins=26)
# Out:
# (array([2, 0, 0, 1, 1, 0, 0, 2, 3, 2, 2, 1, 0, 0, 0, 1, 0, 1, 0, 0, 0, 0, 0,
#         0, 0, 2]),
#  array([ 0.13773721,  0.14989204,  0.16204686,  0.17420168,  0.18635651,
#          0.19851133,  0.21066616,  0.22282098,  0.2349758 ,  0.24713063,
#          0.25928545,  0.27144028,  0.2835951 ,  0.29574992,  0.30790475,
#          0.32005957,  0.3322144 ,  0.34436922,  0.35652404,  0.36867887,
#          0.38083369,  0.39298852,  0.40514334,  0.41729816,  0.42945299,
#          0.44160781,  0.45376264]),
#  <a list of 26 Patch objects>)

# %%
out = m.to_dict()

# %%
with open("test.json", "wb") as f:
    json.dump(out, f)
