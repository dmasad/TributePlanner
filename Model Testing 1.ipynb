# %%
from TributePlanner import *
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
#G = nx.grid_2d_graph(10,10)
#G = nx.watts_strogatz_graph(100, 4, 0.1)
#G = nx.scale_free_graph(10)
#G = G.to_undirected()
G = nx.erdos_renyi_graph(10, 1)

G = nx.relabel_nodes(G, {tup: i for i, tup in enumerate(G.nodes())})
m = Model(G)
m.verbose = True
#m.tribute = 100
#m.actions_per_turn = 10
pos = nx.spring_layout(G)

# %%
for i in range(100):
    m.step()
    print "*\t*\t*"
# Out:
# War between 0 and 2
# War between 9 and 2
# War between 5 and 2
# *	*	*
# War between 8 and 2
# War between 4 and 2
# War between 6 and 2
# *	*	*
# War between 1 and 2
# War between 9 and 2
# *	*	*
# War between 0 and 2
# War between 4 and 2
# War between 5 and 2
# *	*	*
# War between 5 and 2
# War between 6 and 2
# War between 7 and 2
# *	*	*
# War between 8 and 2
# War between 4 and 2
# War between 5 and 2
# *	*	*
# War between 0 and 2
# War between 3 and 2
# War between 7 and 2
# *	*	*
# War between 4 and 2
# War between 5 and 2
# War between 6 and 2
# *	*	*
# War between 1 and 2
# War between 6 and 2
# War between 9 and 2
# *	*	*
# War between 0 and 2
# War between 5 and 2
# War between 6 and 2
# *	*	*
# War between 8 and 2
# War between 9 and 2
# War between 3 and 2
# *	*	*
# War between 0 and 2
# War between 6 and 2
# War between 7 and 2
# *	*	*
# War between 8 and 2
# War between 6 and 2
# *	*	*
# War between 8 and 2
# War between 3 and 2
# War between 7 and 2
# *	*	*
# War between 4 and 2
# War between 7 and 2
# *	*	*
# War between 4 and 2
# War between 6 and 2
# War between 7 and 2
# *	*	*
# War between 8 and 2
# War between 1 and 2
# War between 4 and 2
# *	*	*
# War between 0 and 2
# War between 4 and 2
# War between 7 and 2
# *	*	*
# War between 9 and 2
# War between 4 and 2
# War between 7 and 2
# *	*	*
# War between 8 and 2
# War between 0 and 2
# War between 6 and 2
# *	*	*
# War between 0 and 2
# War between 4 and 2
# War between 5 and 2
# *	*	*
# War between 8 and 2
# War between 1 and 2
# War between 5 and 2
# *	*	*
# War between 0 and 2
# War between 1 and 2
# War between 6 and 2
# *	*	*
# War between 8 and 2
# War between 1 and 2
# War between 4 and 2
# *	*	*
# War between 8 and 2
# War between 3 and 2
# War between 4 and 2
# *	*	*
# War between 8 and 2
# War between 5 and 2
# War between 7 and 2
# *	*	*
# War between 0 and 2
# War between 9 and 2
# War between 5 and 2
# *	*	*
# War between 1 and 2
# War between 4 and 2
# *	*	*
# War between 1 and 2
# 2 paying tribute to 6
# 2 paying tribute to 7
# *	*	*
# War between 3 and 2
# 2 paying tribute to 7
# *	*	*
# War between 3 and 2
# 2 paying tribute to 5
# *	*	*
# War between 3 and 2
# 2 paying tribute to 5
# 2 paying tribute to 6
# *	*	*
# War between 0 and 2
# 2 paying tribute to 1
# 2 paying tribute to 7
# *	*	*
# 2 paying tribute to 8
# 2 paying tribute to 4
# *	*	*
# 2 paying tribute to 1
# 2 paying tribute to 5
# 2 paying tribute to 7
# *	*	*
# War between 0 and 2
# 2 paying tribute to 6
# 2 paying tribute to 7
# *	*	*
# 2 paying tribute to 9
# 2 paying tribute to 7
# *	*	*
# 2 paying tribute to 9
# 2 paying tribute to 3
# *	*	*
# 2 paying tribute to 9
# 2 paying tribute to 7
# *	*	*
# 2 paying tribute to 8
# 2 paying tribute to 1
# 2 paying tribute to 7
# *	*	*
# 2 paying tribute to 8
# 2 paying tribute to 1
# 2 paying tribute to 9
# *	*	*
# 2 paying tribute to 1
# 2 paying tribute to 9
# 2 paying tribute to 7
# *	*	*
# 2 paying tribute to 9
# 2 paying tribute to 3
# 2 paying tribute to 7
# *	*	*
# 2 paying tribute to 4
# 2 paying tribute to 5
# 2 paying tribute to 7
# *	*	*
# 2 paying tribute to 9
# 2 paying tribute to 4
# 2 paying tribute to 6
# *	*	*
# 2 paying tribute to 3
# 2 paying tribute to 7
# *	*	*
# 2 paying tribute to 3
# 2 paying tribute to 5
# *	*	*
# 2 paying tribute to 8
# 2 paying tribute to 9
# 2 paying tribute to 5
# *	*	*
# 2 paying tribute to 8
# 2 paying tribute to 1
# 2 paying tribute to 6
# *	*	*
# 2 paying tribute to 0
# 2 paying tribute to 9
# 2 paying tribute to 7
# *	*	*
# 2 paying tribute to 1
# 2 paying tribute to 3
# 2 paying tribute to 4
# *	*	*
# 2 paying tribute to 1
# 2 paying tribute to 7
# *	*	*
# 2 paying tribute to 3
# 2 paying tribute to 6
# *	*	*
# 2 paying tribute to 8
# 2 paying tribute to 3
# 2 paying tribute to 4
# *	*	*
# 2 paying tribute to 9
# 2 paying tribute to 6
# *	*	*
# 2 paying tribute to 8
# 2 paying tribute to 6
# *	*	*
# 2 paying tribute to 3
# 2 paying tribute to 6
# *	*	*
# 2 paying tribute to 3
# 2 paying tribute to 5
# *	*	*
# 2 paying tribute to 9
# 2 paying tribute to 7
# *	*	*
# 2 paying tribute to 9
# 2 paying tribute to 3
# 2 paying tribute to 7
# *	*	*
# 2 paying tribute to 9
# 2 paying tribute to 3
# *	*	*
# 2 paying tribute to 9
# 2 paying tribute to 4
# 2 paying tribute to 5
# *	*	*
# 2 paying tribute to 0
# 2 paying tribute to 7
# *	*	*
# 2 paying tribute to 0
# 2 paying tribute to 9
# 2 paying tribute to 1
# *	*	*
# 2 paying tribute to 1
# 2 paying tribute to 6
# *	*	*
# 2 paying tribute to 1
# 2 paying tribute to 6
# 2 paying tribute to 7
# *	*	*
# 2 paying tribute to 8
# 2 paying tribute to 9
# 2 paying tribute to 6
# *	*	*
# 2 paying tribute to 3
# 2 paying tribute to 5
# 2 paying tribute to 6
# *	*	*
# 2 paying tribute to 8
# 2 paying tribute to 7
# *	*	*
# 2 paying tribute to 1
# 2 paying tribute to 3
# 2 paying tribute to 9
# *	*	*
# 2 paying tribute to 8
# 2 paying tribute to 4
# 2 paying tribute to 5
# *	*	*
# 2 paying tribute to 3
# 2 paying tribute to 4
# 2 paying tribute to 7
# *	*	*
# 2 paying tribute to 1
# 2 paying tribute to 5
# 2 paying tribute to 6
# *	*	*
# 2 paying tribute to 8
# 2 paying tribute to 0
# 2 paying tribute to 7
# *	*	*
# 2 paying tribute to 8
# 2 paying tribute to 6
# 2 paying tribute to 7
# *	*	*
# 2 paying tribute to 4
# 2 paying tribute to 7
# *	*	*
# 2 paying tribute to 0
# 2 paying tribute to 9
# 2 paying tribute to 6
# *	*	*
# 2 paying tribute to 0
# 2 paying tribute to 4
# 2 paying tribute to 6
# *	*	*
# 2 paying tribute to 0
# 2 paying tribute to 1
# 2 paying tribute to 5
# *	*	*
# 2 paying tribute to 0
# 2 paying tribute to 4
# 2 paying tribute to 7
# *	*	*
# 2 paying tribute to 0
# 2 paying tribute to 3
# 2 paying tribute to 5
# *	*	*
# 2 paying tribute to 8
# 2 paying tribute to 9
# 2 paying tribute to 3
# *	*	*
# 2 paying tribute to 1
# 2 paying tribute to 4
# *	*	*
# 2 paying tribute to 3
# 2 paying tribute to 5
# 2 paying tribute to 7
# *	*	*
# 2 paying tribute to 0
# 2 paying tribute to 3
# 2 paying tribute to 4
# *	*	*
# 2 paying tribute to 1
# 2 paying tribute to 7
# *	*	*
# 2 paying tribute to 8
# 2 paying tribute to 9
# 2 paying tribute to 4
# *	*	*
# 2 paying tribute to 0
# 2 paying tribute to 5
# *	*	*
# 2 paying tribute to 8
# 2 paying tribute to 5
# 2 paying tribute to 7
# *	*	*
# 2 paying tribute to 0
# 2 paying tribute to 9
# 2 paying tribute to 5
# *	*	*
# 2 paying tribute to 0
# 2 paying tribute to 3
# *	*	*
# 2 paying tribute to 9
# 2 paying tribute to 3
# *	*	*
# 2 paying tribute to 1
# 2 paying tribute to 4
# *	*	*
# 2 paying tribute to 0
# 2 paying tribute to 1
# 2 paying tribute to 8
# *	*	*
# 2 paying tribute to 8
# 2 paying tribute to 9
# 2 paying tribute to 4
# *	*	*
# 2 paying tribute to 3
# 2 paying tribute to 6
# *	*	*
# 2 paying tribute to 8
# 2 paying tribute to 1
# 2 paying tribute to 3
# *	*	*
# 2 paying tribute to 4
# 2 paying tribute to 5
# 2 paying tribute to 6
# *	*	*
# 2 paying tribute to 0
# 2 paying tribute to 3
# 2 paying tribute to 4
# *	*	*
# 2 paying tribute to 3
# 2 paying tribute to 4
# 2 paying tribute to 7
# *	*	*

# %%
nx.draw(m.graph, pos=pos, node_size=[m.agents[i].wealth for i in m.agents])

# %%
plt.plot(m.war_series)

# %%
for s in m.agent_wealth_series.values():
    plt.plot(s)
